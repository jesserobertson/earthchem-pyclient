# %% [markdown]
# ### Schema validation against examples

# %%
from earthchem.validation import *
# Out:
# Traceback (most recent call last):
#
#   File "/home/rob65g/.local/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-fcf5ec7a178f>", line 1, in <module>
#     from earthchem.validation import *
#
#   File "/home/rob65g/Documents/earthchem/earthchem/validation.py", line 78
#     if not validators
#                      ^
# SyntaxError: invalid syntax

# %%
self = QueryElement('Reference')
# Out:
# getting valid keys
# getting valid values
